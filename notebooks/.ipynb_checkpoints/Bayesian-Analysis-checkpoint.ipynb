# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display

plt.style.use(["ggplot", "seaborn-poster"])
# %matplotlib inline

# %% [markdown]
# # Post Level - Bayesian Analysis

# %%
PATH_TO_LOG = '../logs/post_bayesian_logger_oof.csv'
data = pd.read_csv(PATH_TO_LOG)

# %%
display(data.head(n = 3))
# Out:
#    id                                              model  \
# 0   0  <class 'sklearn.linear_model._logistic.Logisti...
# 1   1          <class 'lightgbm.sklearn.LGBMClassifier'>
# 2   2  <class 'sklearn.linear_model._logistic.Logisti...
#
#                                   parameters  \
# 0             {'C': 7.0, 'random_state': 42}
# 1  {'n_estimators': 500, 'random_state': 42}
# 2             {'C': 1.0, 'random_state': 42}
#
#                                              columns  \
# 0                        ['social_prepocessed_text']
# 1  ['text', 'happy', 'angry', 'surprise', 'sad', ...
# 2                                           ['text']
#
#                                         transformers  \
# 0  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 1  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 2  [{'name': 'word_tfidf', 'algorithm': <class 's...
#
#                                    column_transforms  valid_strategy  \
# 0  {'remainder': StandardScaler(copy=True, with_m...               1
# 1  {'remainder': StandardScaler(copy=True, with_m...               1
# 2  {'remainder': StandardScaler(copy=True, with_m...               1
#
#    one_fold              observation  post_accuracy  post_precision  \
# 0     False  BayesianOptimizationOOF          0.281           0.476
# 1     False  BayesianOptimizationOOF          0.280           0.452
# 2     False  BayesianOptimizationOOF          0.296           0.494
#
#    post_recall  post_error  user_accuracy  user_precision  user_recall  \
# 0        0.407       0.189          0.346           0.585        0.459
# 1        0.424       0.171          0.369           0.573        0.509
# 2        0.425       0.181          0.378           0.598        0.508
#
#    user_error
# 0       0.163
# 1       0.156
# 2       0.151

# %%
plt.figure(figsize = (14, 10))
plt.plot(data['id'].values, data['user_accuracy'].values)
plt.xlabel("Experiment Id")
plt.ylabel("User Accuracy")
plt.show()

# %%
data.groupby("model")["user_accuracy"].describe()
# Out:
#                                                     count      mean       std  \
# model
# <class 'lightgbm.sklearn.LGBMClassifier'>           104.0  0.354404  0.014613
# <class 'sklearn.ensemble._forest.RandomForestCl...   82.0  0.373902  0.013557
# <class 'sklearn.ensemble._weight_boosting.AdaBo...   36.0  0.357833  0.018105
# <class 'sklearn.linear_model._logistic.Logistic...   83.0  0.359928  0.013841
# <class 'sklearn.svm._classes.SVC'>                   79.0  0.359671  0.014615
#
#                                                       min     25%     50%  \
# model
# <class 'lightgbm.sklearn.LGBMClassifier'>           0.307  0.3455  0.3545
# <class 'sklearn.ensemble._forest.RandomForestCl...  0.344  0.3620  0.3740
# <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.307  0.3440  0.3610
# <class 'sklearn.linear_model._logistic.Logistic...  0.319  0.3510  0.3620
# <class 'sklearn.svm._classes.SVC'>                  0.328  0.3460  0.3580
#
#                                                        75%    max
# model
# <class 'lightgbm.sklearn.LGBMClassifier'>           0.3650  0.388
# <class 'sklearn.ensemble._forest.RandomForestCl...  0.3845  0.401
# <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.3740  0.388
# <class 'sklearn.linear_model._logistic.Logistic...  0.3690  0.394
# <class 'sklearn.svm._classes.SVC'>                  0.3740  0.388

# %%
data.groupby("columns")["user_accuracy"].describe()
# Out:
#                                                     count      mean       std  \
# columns
# ['social_prepocessed_text', 'happy', 'angry', '...  120.0  0.358042  0.015497
# ['social_prepocessed_text']                          64.0  0.361266  0.014894
# ['text', 'happy', 'angry', 'surprise', 'sad', '...   63.0  0.362714  0.015504
# ['text']                                            137.0  0.363146  0.017186
#
#                                                       min     25%     50%  \
# columns
# ['social_prepocessed_text', 'happy', 'angry', '...  0.307  0.3460  0.3580
# ['social_prepocessed_text']                         0.330  0.3505  0.3635
# ['text', 'happy', 'angry', 'surprise', 'sad', '...  0.321  0.3530  0.3620
# ['text']                                            0.307  0.3510  0.3620
#
#                                                       75%    max
# columns
# ['social_prepocessed_text', 'happy', 'angry', '...  0.369  0.394
# ['social_prepocessed_text']                         0.374  0.390
# ['text', 'happy', 'angry', 'surprise', 'sad', '...  0.374  0.394
# ['text']                                            0.376  0.401

# %%
display(data.sort_values(by = "user_accuracy", ascending = False).head(n = 10))
# Out:
#       id                                              model  \
# 244  244  <class 'sklearn.ensemble._forest.RandomForestC...
# 293  293  <class 'sklearn.ensemble._forest.RandomForestC...
# 118  118  <class 'sklearn.ensemble._forest.RandomForestC...
# 353  353  <class 'sklearn.ensemble._forest.RandomForestC...
# 281  281  <class 'sklearn.linear_model._logistic.Logisti...
# 308  308  <class 'sklearn.ensemble._forest.RandomForestC...
# 175  175  <class 'sklearn.ensemble._forest.RandomForestC...
# 307  307  <class 'sklearn.ensemble._forest.RandomForestC...
# 313  313  <class 'sklearn.ensemble._forest.RandomForestC...
# 311  311  <class 'sklearn.ensemble._forest.RandomForestC...
#
#                                     parameters  \
# 244  {'n_estimators': 250, 'random_state': 42}
# 293  {'n_estimators': 250, 'random_state': 42}
# 118  {'n_estimators': 250, 'random_state': 42}
# 353  {'n_estimators': 450, 'random_state': 42}
# 281             {'C': 0.7, 'random_state': 42}
# 308  {'n_estimators': 450, 'random_state': 42}
# 175  {'n_estimators': 300, 'random_state': 42}
# 307  {'n_estimators': 450, 'random_state': 42}
# 313  {'n_estimators': 200, 'random_state': 42}
# 311  {'n_estimators': 200, 'random_state': 42}
#
#                                                columns  \
# 244                                           ['text']
# 293                                           ['text']
# 118                                           ['text']
# 353  ['social_prepocessed_text', 'happy', 'angry', ...
# 281  ['text', 'happy', 'angry', 'surprise', 'sad', ...
# 308                                           ['text']
# 175  ['text', 'happy', 'angry', 'surprise', 'sad', ...
# 307                                           ['text']
# 313                                           ['text']
# 311                                           ['text']
#
#                                           transformers  \
# 244  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 293  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 118  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 353  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 281  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 308  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 175  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 307  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 313  [{'name': 'word_tfidf', 'algorithm': <class 's...
# 311  [{'name': 'word_tfidf', 'algorithm': <class 's...
#
#                                      column_transforms  valid_strategy  \
# 244  {'remainder': StandardScaler(copy=True, with_m...               1
# 293  {'remainder': StandardScaler(copy=True, with_m...               1
# 118  {'remainder': StandardScaler(copy=True, with_m...               1
# 353  {'remainder': StandardScaler(copy=True, with_m...               1
# 281  {'remainder': StandardScaler(copy=True, with_m...               1
# 308  {'remainder': StandardScaler(copy=True, with_m...               1
# 175  {'remainder': StandardScaler(copy=True, with_m...               1
# 307  {'remainder': StandardScaler(copy=True, with_m...               1
# 313  {'remainder': StandardScaler(copy=True, with_m...               1
# 311  {'remainder': StandardScaler(copy=True, with_m...               1
#
#      one_fold              observation  post_accuracy  post_precision  \
# 244     False  BayesianOptimizationOOF          0.304           0.481
# 293     False  BayesianOptimizationOOF          0.304           0.481
# 118     False  BayesianOptimizationOOF          0.304           0.481
# 353     False  BayesianOptimizationOOF          0.305           0.490
# 281     False  BayesianOptimizationOOF          0.300           0.515
# 308     False  BayesianOptimizationOOF          0.309           0.488
# 175     False  BayesianOptimizationOOF          0.297           0.472
# 307     False  BayesianOptimizationOOF          0.301           0.470
# 313     False  BayesianOptimizationOOF          0.303           0.479
# 311     False  BayesianOptimizationOOF          0.303           0.479
#
#      post_recall  post_error  user_accuracy  user_precision  user_recall  \
# 244        0.453       0.163          0.401           0.572        0.574
# 293        0.453       0.163          0.401           0.572        0.574
# 118        0.453       0.163          0.401           0.572        0.574
# 353        0.448       0.168          0.394           0.577        0.555
# 281        0.418       0.186          0.394           0.623        0.518
# 308        0.457       0.163          0.392           0.562        0.564
# 175        0.444       0.168          0.390           0.569        0.554
# 307        0.457       0.158          0.390           0.561        0.561
# 313        0.451       0.163          0.390           0.569        0.554
# 311        0.451       0.163          0.390           0.569        0.554
#
#      user_error
# 244       0.122
# 293       0.122
# 118       0.122
# 353       0.128
# 281       0.156
# 308       0.124
# 175       0.133
# 307       0.124
# 313       0.133
# 311       0.133

# %%
display(data.iloc[353].values)
# Out:
# array([353, "<class 'sklearn.ensemble._forest.RandomForestClassifier'>",
#        "{'n_estimators': 450, 'random_state': 42}",
#        "['social_prepocessed_text', 'happy', 'angry', 'surprise', 'sad', 'fear']",
#        "[{'name': 'word_tfidf', 'algorithm': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>, 'parameters': {'analyzer': 'word', 'ngram_range': (1, 1)}, 'columns': 'social_prepocessed_text'}]",
#        "{'remainder': StandardScaler(copy=True, with_mean=True, with_std=True), 'n_jobs': -1}",
#        1, False, 'BayesianOptimizationOOF', 0.305, 0.49,
#        0.44799999999999995, 0.168, 0.39399999999999996,
#        0.5770000000000001, 0.555, 0.128], dtype=object)

# %%
for idx, group in data.groupby("model"):
    print(f"Models: {idx}")
    display(group.sort_values(by = ["user_accuracy", "id"], ascending = (False, False)).head(n = 1).values)
# Out:
# Models: <class 'lightgbm.sklearn.LGBMClassifier'>
# array([[274, "<class 'lightgbm.sklearn.LGBMClassifier'>",
#         "{'n_estimators': 50, 'random_state': 42}", "['text']",
#         '[{\'name\': \'word_tfidf\', \'algorithm\': <class \'sklearn.feature_extraction.text.TfidfVectorizer\'>, \'parameters\': {\'analyzer\': \'word\', \'ngram_range\': (1, 5), \'token_pattern\': \'(?u)\\\\b\\\\w\\\\w+\\\\b|!|,|.|\\\\?|\\\\"|\\\\\\\'\'}, \'columns\': \'text\'}]',
#         "{'remainder': StandardScaler(copy=True, with_mean=True, with_std=True), 'n_jobs': -1}",
#         1, False, 'BayesianOptimizationOOF', 0.29, 0.472, 0.428,
#         0.17800000000000002, 0.388, 0.617, 0.511, 0.16699999999999998]],
#       dtype=object)
# Models: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# array([[293, "<class 'sklearn.ensemble._forest.RandomForestClassifier'>",
#         "{'n_estimators': 250, 'random_state': 42}", "['text']",
#         "[{'name': 'word_tfidf', 'algorithm': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>, 'parameters': {'analyzer': 'word', 'ngram_range': (1, 2)}, 'columns': 'text'}]",
#         "{'remainder': StandardScaler(copy=True, with_mean=True, with_std=True), 'n_jobs': -1}",
#         1, False, 'BayesianOptimizationOOF', 0.304, 0.48100000000000004,
#         0.45299999999999996, 0.163, 0.401, 0.5720000000000001, 0.574,
#         0.122]], dtype=object)
# Models: <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# array([[225,
#         "<class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>",
#         "{'n_estimators': 25, 'random_state': 42}",
#         "['social_prepocessed_text']",
#         '[{\'name\': \'word_tfidf\', \'algorithm\': <class \'sklearn.feature_extraction.text.TfidfVectorizer\'>, \'parameters\': {\'analyzer\': \'word\', \'ngram_range\': (1, 1), \'token_pattern\': \'(?u)\\\\b\\\\w\\\\w+\\\\b|!|,|.|\\\\?|\\\\"|\\\\\\\'\'}, \'columns\': \'social_prepocessed_text\'}]',
#         "{'remainder': StandardScaler(copy=True, with_mean=True, with_std=True), 'n_jobs': -1}",
#         1, False, 'BayesianOptimizationOOF', 0.304, 0.505, 0.434,
#         0.19399999999999998, 0.38799999999999996, 0.633, 0.5, 0.193]],
#       dtype=object)
# Models: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# array([[281,
#         "<class 'sklearn.linear_model._logistic.LogisticRegression'>",
#         "{'C': 0.7, 'random_state': 42}",
#         "['text', 'happy', 'angry', 'surprise', 'sad', 'fear']",
#         "[{'name': 'word_tfidf', 'algorithm': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>, 'parameters': {'analyzer': 'word', 'ngram_range': (1, 5)}, 'columns': 'text'}]",
#         "{'remainder': StandardScaler(copy=True, with_mean=True, with_std=True), 'n_jobs': -1}",
#         1, False, 'BayesianOptimizationOOF', 0.3, 0.515, 0.418,
#         0.18600000000000005, 0.39399999999999996, 0.623, 0.518, 0.156]],
#       dtype=object)
# Models: <class 'sklearn.svm._classes.SVC'>
# array([[346, "<class 'sklearn.svm._classes.SVC'>",
#         "{'C': 1.0, 'random_state': 42}", "['text']",
#         "[{'name': 'word_tfidf', 'algorithm': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>, 'parameters': {'analyzer': 'word', 'ngram_range': (1, 3)}, 'columns': 'text'}]",
#         "{'remainder': StandardScaler(copy=True, with_mean=True, with_std=True), 'n_jobs': -1}",
#         1, False, 'BayesianOptimizationOOF', 0.304, 0.4970000000000001,
#         0.439, 0.162, 0.388, 0.5670000000000001, 0.55, 0.128]],
#       dtype=object)

# %%
PATH_TO_LOG = '../logs/bayesian_logger_oof_users.csv'
data = pd.read_csv(PATH_TO_LOG)

# %%
plt.figure(figsize = (14, 10))
plt.plot(data['id'], data['user_accuracy'])
plt.xlabel("Id")
plt.ylabel("User Accuracy")
plt.show()

# %%
data.groupby("model")["user_accuracy"].describe()

# %%
data.groupby("columns")["user_accuracy"].describe()

# %%
data['post_accuracy'].corr(data.user_accuracy)

# %%
display(data.sort_values(by = "user_accuracy", ascending = False).head(n = 50))

# %%
display(data.iloc[31].values)

# %%
display(data.iloc[176].values)

# %%
display(data.iloc[290].values)

# %%
for idx, group in data.groupby("model"):
    print(idx)
    display(group.sort_values(by = ["user_accuracy", "id"], ascending = (False, False)).head(n = 1).values)
